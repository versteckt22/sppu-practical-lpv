# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Normalize Data
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape for CNN
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# Build CNN Model
model = Sequential()

# Convolution Layer
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)))

# Pooling Layer
model.add(MaxPooling2D((2,2)))

# Flatten Layer
model.add(Flatten())

# Dense Layers
model.add(Dense(128, activation='relu'))

# Output Layer
model.add(Dense(10, activation='softmax'))

# Compile Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# /home/atharva/myenv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1778545686.943850  146540 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=128
)

# Evaluate Model
loss, accuracy = model.evaluate(x_test, y_test)

print("\nTest Accuracy:", accuracy)
# Out:
# Epoch 1/5
# W0000 00:00:1778545716.070304  146540 cpu_allocator_impl.cc:82] Allocation of 188160000 exceeds 10% of free system memory.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 25ms/step - accuracy: 0.8375 - loss: 0.4647
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.8881 - loss: 0.3155
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.9022 - loss: 0.2730
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9124 - loss: 0.2419
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 27ms/step - accuracy: 0.9217 - loss: 0.2167
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 47s 151ms/step - accuracy: 0.9062 - loss: 0.3893
# W0000 00:00:1778545778.858327  146540 cpu_allocator_impl.cc:82] Allocation of 31360000 exceeds 10% of free system memory.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9067 - loss: 0.2653
#
# Test Accuracy: 0.9067000150680542

# %%
predictions = model.predict(x_test[:10])

# Fashion Labels
labels = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]

print("\nClassification Results:\n")

for i in range(10):

    predicted_label = predictions[i].argmax()

    print("Image", i+1)
    print("Predicted:", labels[predicted_label])
    print("Actual:", labels[y_test[i]])
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
#
# Classification Results:
#
# Image 1
# Predicted: Ankle boot
# Actual: Ankle boot
#
# Image 2
# Predicted: Pullover
# Actual: Pullover
#
# Image 3
# Predicted: Trouser
# Actual: Trouser
#
# Image 4
# Predicted: Trouser
# Actual: Trouser
#
# Image 5
# Predicted: Shirt
# Actual: Shirt
#
# Image 6
# Predicted: Trouser
# Actual: Trouser
#
# Image 7
# Predicted: Coat
# Actual: Coat
#
# Image 8
# Predicted: Shirt
# Actual: Shirt
#
# Image 9
# Predicted: Sandal
# Actual: Sandal
#
# Image 10
# Predicted: Sneaker
# Actual: Sneaker
