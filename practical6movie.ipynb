# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

# %%
x_train = pad_sequences(x_train, maxlen=200)
x_test = pad_sequences(x_test, maxlen=200)

# %%
model = Sequential()

# Embedding Layer
model.add(Embedding(input_dim=10000, output_dim=32, input_length=200))

# Flatten Layer
model.add(Flatten())

# Hidden Layers
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))

# Output Layer
model.add(Dense(1, activation='sigmoid'))

# Compile Model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# /home/atharva/myenv/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=128,
    validation_split=0.2
)

# Evaluate Model
loss, accuracy = model.evaluate(x_test, y_test)

print("\nTest Accuracy:", accuracy)
# Out:
# Epoch 1/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7293 - loss: 0.4996 - val_accuracy: 0.8558 - val_loss: 0.3351
# Epoch 2/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9362 - loss: 0.1720 - val_accuracy: 0.8514 - val_loss: 0.3489
# Epoch 3/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9912 - loss: 0.0346 - val_accuracy: 0.8568 - val_loss: 0.4424
# Epoch 4/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9991 - loss: 0.0062 - val_accuracy: 0.8578 - val_loss: 0.4965
# Epoch 5/5
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 0.8560 - val_loss: 0.5558
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8476 - loss: 0.5946
#
# Test Accuracy: 0.8476399779319763

# %%
# Predict 20 reviews
predictions = model.predict(x_test[:20])

print("\nClassification Results:\n")

for i in range(20):

    probability = predictions[i][0]

    if probability > 0.5:
        result = "Positive Review"
    else:
        result = "Negative Review"

    print("Review", i+1)
    print("Prediction =", probability)
    print("Classification =", result)
    print()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
#
# Classification Results:
#
# Review 1
# Prediction = 0.9111826
# Classification = Positive Review
#
# Review 2
# Prediction = 0.99997807
# Classification = Positive Review
#
# Review 3
# Prediction = 0.92929316
# Classification = Positive Review
#
# Review 4
# Prediction = 0.015016583
# Classification = Negative Review
#
# Review 5
# Prediction = 0.9997742
# Classification = Positive Review
#
# Review 6
# Prediction = 0.9466294
# Classification = Positive Review
#
# Review 7
# Prediction = 0.9997995
# Classification = Positive Review
#
# Review 8
# Prediction = 3.4699056e-05
# Classification = Negative Review
#
# Review 9
# Prediction = 0.99988246
# Classification = Positive Review
#
# Review 10
# Prediction = 0.99980676
# Classification = Positive Review
#
# Review 11
# Prediction = 0.99991465
# Classification = Positive Review
#
# Review 12
# Prediction = 3.027774e-06
# Classification = Negative Review
#
# Review 13
# Prediction = 1.3822402e-05
# Classification = Negative Review
#
# Review 14
# Prediction = 0.00029861534
# Classification = Negative Review
#
# Review 15
# Prediction = 0.9999692
# Classification = Positive Review
#
# Review 16
# Prediction = 2.7532758e-06
# Classification = Negative Review
#
# Review 17
# Prediction = 0.9999935
# Classification = Positive Review
#
# Review 18
# Prediction = 0.012096692
# Classification = Negative Review
#
# Review 19
# Prediction = 3.5216954e-07
# Classification = Negative Review
#
# Review 20
# Prediction = 0.0007564463
# Classification = Negative Review
